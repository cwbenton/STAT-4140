# %%
import tensorflow as tf

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout,BatchNormalization

# %% [markdown]
# ## Dataset Exploration

# %%
cif_data = tf.keras.datasets.cifar10

# %%
dir(cif_data)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'load_data']

# %%
cif_data.load_data
# Out:
# <function keras.src.datasets.cifar10.load_data()>

# %%
a,b = cif_data.load_data()

# %%
a[0].shape
# Out:
# (50000, 32, 32, 3)

# %%
a[1].shape
# Out:
# (50000, 1)

# %%
train = a

# %%
b[0].shape
# Out:
# (10000, 32, 32, 3)

# %%
b[1].shape
# Out:
# (10000, 1)

# %%
test = b

# %%
train_x = train[0]
train_y = train[1]

test_x = test[0]
test_y = test[1]

# %%
import matplotlib.pyplot as plt
plt.imshow(train_x[0],cmap='gray')

# %%
train_y[0]
# Out:
# array([6], dtype=uint8)

# %%
#Normalize the data
train_x = train_x.astype('float32') / 255.0
test_x = test_x.astype('float32') / 255.0

# %% [markdown]
# ## Build the model

# %%
model = Sequential([
    Flatten(input_shape=(32, 32, 3)),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_x, train_y, epochs=50, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/50
# 1250/1250 - 6s - loss: 1.9659 - accuracy: 0.3033 - val_loss: 1.7739 - val_accuracy: 0.3724 - 6s/epoch - 5ms/step
# Epoch 2/50
# 1250/1250 - 5s - loss: 1.7731 - accuracy: 0.3631 - val_loss: 1.9264 - val_accuracy: 0.3225 - 5s/epoch - 4ms/step
# Epoch 3/50
# 1250/1250 - 5s - loss: 1.7283 - accuracy: 0.3821 - val_loss: 1.7118 - val_accuracy: 0.3790 - 5s/epoch - 4ms/step
# Epoch 4/50
# 1250/1250 - 5s - loss: 1.7037 - accuracy: 0.3904 - val_loss: 1.7395 - val_accuracy: 0.3883 - 5s/epoch - 4ms/step
# Epoch 5/50
# 1250/1250 - 6s - loss: 1.6910 - accuracy: 0.3980 - val_loss: 1.6176 - val_accuracy: 0.4311 - 6s/epoch - 4ms/step
# Epoch 6/50
# 1250/1250 - 6s - loss: 1.6691 - accuracy: 0.4032 - val_loss: 1.5750 - val_accuracy: 0.4389 - 6s/epoch - 4ms/step
# Epoch 7/50
# 1250/1250 - 6s - loss: 1.6462 - accuracy: 0.4113 - val_loss: 1.5799 - val_accuracy: 0.4471 - 6s/epoch - 5ms/step
# Epoch 8/50
# 1250/1250 - 5s - loss: 1.6268 - accuracy: 0.4189 - val_loss: 1.5612 - val_accuracy: 0.4443 - 5s/epoch - 4ms/step
# Epoch 9/50
# 1250/1250 - 6s - loss: 1.6115 - accuracy: 0.4223 - val_loss: 1.5516 - val_accuracy: 0.4482 - 6s/epoch - 5ms/step
# Epoch 10/50
# 1250/1250 - 6s - loss: 1.6012 - accuracy: 0.4306 - val_loss: 1.5402 - val_accuracy: 0.4594 - 6s/epoch - 5ms/step
# Epoch 11/50
# 1250/1250 - 5s - loss: 1.5900 - accuracy: 0.4365 - val_loss: 1.5363 - val_accuracy: 0.4542 - 5s/epoch - 4ms/step
# Epoch 12/50
# 1250/1250 - 6s - loss: 1.5888 - accuracy: 0.4360 - val_loss: 1.5426 - val_accuracy: 0.4569 - 6s/epoch - 4ms/step
# Epoch 13/50
# 1250/1250 - 6s - loss: 1.5820 - accuracy: 0.4372 - val_loss: 1.5422 - val_accuracy: 0.4529 - 6s/epoch - 4ms/step
# Epoch 14/50
# 1250/1250 - 6s - loss: 1.5861 - accuracy: 0.4342 - val_loss: 1.5715 - val_accuracy: 0.4388 - 6s/epoch - 4ms/step
# Epoch 15/50
# 1250/1250 - 5s - loss: 1.5770 - accuracy: 0.4412 - val_loss: 1.5472 - val_accuracy: 0.4501 - 5s/epoch - 4ms/step
# Epoch 16/50
# 1250/1250 - 6s - loss: 1.5669 - accuracy: 0.4423 - val_loss: 1.5287 - val_accuracy: 0.4641 - 6s/epoch - 5ms/step
# Epoch 17/50
# 1250/1250 - 6s - loss: 1.5645 - accuracy: 0.4448 - val_loss: 1.5476 - val_accuracy: 0.4590 - 6s/epoch - 5ms/step
# Epoch 18/50
# 1250/1250 - 5s - loss: 1.5437 - accuracy: 0.4487 - val_loss: 1.5223 - val_accuracy: 0.4634 - 5s/epoch - 4ms/step
# Epoch 19/50
# 1250/1250 - 5s - loss: 1.5450 - accuracy: 0.4482 - val_loss: 1.4800 - val_accuracy: 0.4762 - 5s/epoch - 4ms/step
# Epoch 20/50
# 1250/1250 - 6s - loss: 1.5316 - accuracy: 0.4543 - val_loss: 1.4704 - val_accuracy: 0.4826 - 6s/epoch - 4ms/step
# Epoch 21/50
# 1250/1250 - 6s - loss: 1.5357 - accuracy: 0.4547 - val_loss: 1.4807 - val_accuracy: 0.4718 - 6s/epoch - 5ms/step
# Epoch 22/50
# 1250/1250 - 6s - loss: 1.5279 - accuracy: 0.4563 - val_loss: 1.5166 - val_accuracy: 0.4583 - 6s/epoch - 4ms/step
# Epoch 23/50
# 1250/1250 - 6s - loss: 1.5243 - accuracy: 0.4570 - val_loss: 1.4892 - val_accuracy: 0.4787 - 6s/epoch - 4ms/step
# Epoch 24/50
# 1250/1250 - 6s - loss: 1.5137 - accuracy: 0.4624 - val_loss: 1.5286 - val_accuracy: 0.4634 - 6s/epoch - 4ms/step
# Epoch 25/50
# 1250/1250 - 6s - loss: 1.5145 - accuracy: 0.4603 - val_loss: 1.4530 - val_accuracy: 0.4838 - 6s/epoch - 4ms/step
# Epoch 26/50
# 1250/1250 - 6s - loss: 1.5100 - accuracy: 0.4621 - val_loss: 1.5057 - val_accuracy: 0.4613 - 6s/epoch - 4ms/step
# Epoch 27/50
# 1250/1250 - 6s - loss: 1.5048 - accuracy: 0.4636 - val_loss: 1.4605 - val_accuracy: 0.4722 - 6s/epoch - 5ms/step
# Epoch 28/50
# 1250/1250 - 5s - loss: 1.5054 - accuracy: 0.4661 - val_loss: 1.4938 - val_accuracy: 0.4701 - 5s/epoch - 4ms/step
# Epoch 29/50
# 1250/1250 - 6s - loss: 1.5079 - accuracy: 0.4663 - val_loss: 1.5255 - val_accuracy: 0.4577 - 6s/epoch - 4ms/step
# Epoch 30/50
# 1250/1250 - 6s - loss: 1.4973 - accuracy: 0.4667 - val_loss: 1.4408 - val_accuracy: 0.4904 - 6s/epoch - 5ms/step
# Epoch 31/50
# 1250/1250 - 5s - loss: 1.5064 - accuracy: 0.4633 - val_loss: 1.4279 - val_accuracy: 0.4950 - 5s/epoch - 4ms/step
# Epoch 32/50
# 1250/1250 - 6s - loss: 1.4964 - accuracy: 0.4678 - val_loss: 1.4603 - val_accuracy: 0.4869 - 6s/epoch - 5ms/step
# Epoch 33/50
# 1250/1250 - 6s - loss: 1.4999 - accuracy: 0.4671 - val_loss: 1.4855 - val_accuracy: 0.4824 - 6s/epoch - 5ms/step
# Epoch 34/50
# 1250/1250 - 6s - loss: 1.5066 - accuracy: 0.4676 - val_loss: 1.5199 - val_accuracy: 0.4730 - 6s/epoch - 5ms/step
# Epoch 35/50
# 1250/1250 - 5s - loss: 1.5038 - accuracy: 0.4660 - val_loss: 1.4765 - val_accuracy: 0.4773 - 5s/epoch - 4ms/step
# Epoch 36/50
# 1250/1250 - 5s - loss: 1.4923 - accuracy: 0.4715 - val_loss: 1.4561 - val_accuracy: 0.4882 - 5s/epoch - 4ms/step
# Epoch 37/50
# 1250/1250 - 5s - loss: 1.4925 - accuracy: 0.4703 - val_loss: 1.4287 - val_accuracy: 0.4935 - 5s/epoch - 4ms/step
# Epoch 38/50
# 1250/1250 - 6s - loss: 1.4894 - accuracy: 0.4703 - val_loss: 1.4894 - val_accuracy: 0.4720 - 6s/epoch - 5ms/step
# Epoch 39/50
# 1250/1250 - 6s - loss: 1.4897 - accuracy: 0.4725 - val_loss: 1.4648 - val_accuracy: 0.4819 - 6s/epoch - 5ms/step
# Epoch 40/50
# 1250/1250 - 6s - loss: 1.4744 - accuracy: 0.4752 - val_loss: 1.4501 - val_accuracy: 0.4849 - 6s/epoch - 5ms/step
# Epoch 41/50
# 1250/1250 - 6s - loss: 1.4751 - accuracy: 0.4759 - val_loss: 1.4655 - val_accuracy: 0.4805 - 6s/epoch - 5ms/step
# Epoch 42/50
# 1250/1250 - 6s - loss: 1.4791 - accuracy: 0.4765 - val_loss: 1.4379 - val_accuracy: 0.4924 - 6s/epoch - 5ms/step
# Epoch 43/50
# 1250/1250 - 5s - loss: 1.4775 - accuracy: 0.4755 - val_loss: 1.4479 - val_accuracy: 0.4859 - 5s/epoch - 4ms/step
# Epoch 44/50
# 1250/1250 - 5s - loss: 1.4817 - accuracy: 0.4750 - val_loss: 1.4440 - val_accuracy: 0.4919 - 5s/epoch - 4ms/step
# Epoch 45/50
# 1250/1250 - 5s - loss: 1.4727 - accuracy: 0.4753 - val_loss: 1.4278 - val_accuracy: 0.4894 - 5s/epoch - 4ms/step
# Epoch 46/50
# 1250/1250 - 5s - loss: 1.4749 - accuracy: 0.4771 - val_loss: 1.4879 - val_accuracy: 0.4749 - 5s/epoch - 4ms/step
# Epoch 47/50
# 1250/1250 - 5s - loss: 1.4727 - accuracy: 0.4743 - val_loss: 1.4301 - val_accuracy: 0.4933 - 5s/epoch - 4ms/step
# Epoch 48/50
# 1250/1250 - 6s - loss: 1.4666 - accuracy: 0.4800 - val_loss: 1.4390 - val_accuracy: 0.4931 - 6s/epoch - 5ms/step
# Epoch 49/50
# 1250/1250 - 5s - loss: 1.4656 - accuracy: 0.4843 - val_loss: 1.4791 - val_accuracy: 0.4743 - 5s/epoch - 4ms/step
# Epoch 50/50
# 1250/1250 - 5s - loss: 1.4645 - accuracy: 0.4810 - val_loss: 1.4548 - val_accuracy: 0.4898 - 5s/epoch - 4ms/step

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_x,  test_y, verbose=2)
# Out:
# 313/313 - 0s - loss: 1.4304 - accuracy: 0.4901 - 401ms/epoch - 1ms/step
